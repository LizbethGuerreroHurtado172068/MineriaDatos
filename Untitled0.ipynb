# %% [markdown]
# <a href="https://colab.research.google.com/github/LizbethGuerreroHurtado172068/MineriaDatos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria de Datos

# %% [markdown]
# ## Primer parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# Qué es la mineria de datos?

# %% [markdown]
# #### Ciencia de Datos
